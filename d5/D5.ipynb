# %%
with open("input") as f:
    data = f.readlines()

class Rule ():
    def __init__(self, v, less_than, pos):
        self.value
        self.less_than

    def __lt__(self, other):
        

rules = data[:data.index('\n')]
rules = [[entry.strip("\n").split("|"), i] for i, entry in enumerate(rules)]
sorted(rules, key=lambda x: x[0][1])
# Out:
# [[['75', '11'], 75],
#  [['63', '11'], 114],
#  [['47', '11'], 214],
#  [['98', '11'], 247],
#  [['58', '11'], 254],
#  [['32', '11'], 285],
#  [['99', '11'], 343],
#  [['96', '11'], 365],
#  [['78', '11'], 533],
#  [['46', '11'], 557],
#  [['66', '11'], 564],
#  [['69', '11'], 614],
#  [['28', '11'], 645],
#  [['71', '11'], 675],
#  [['49', '11'], 696],
#  [['48', '11'], 770],
#  [['57', '11'], 856],
#  [['38', '11'], 894],
#  [['56', '11'], 917],
#  [['94', '11'], 932],
#  [['17', '11'], 967],
#  [['52', '11'], 1029],
#  [['74', '11'], 1128],
#  [['24', '11'], 1144],
#  [['53', '12'], 157],
#  [['44', '12'], 182],
#  [['58', '12'], 269],
#  [['32', '12'], 280],
#  [['89', '12'], 303],
#  [['27', '12'], 416],
#  [['19', '12'], 434],
#  [['36', '12'], 487],
#  [['92', '12'], 506],
#  [['78', '12'], 532],
#  [['66', '12'], 580],
#  [['69', '12'], 634],
#  [['29', '12'], 739],
#  [['48', '12'], 758],
#  [['13', '12'], 791],
#  [['87', '12'], 807],
#  [['38', '12'], 889],
# ...
